# %% [markdown]
# Lista de Exercícios (Módulo 1)
#
# Questão 1: Crie uma variável chamada cidade com o nome da sua cidade e uma variável populacao. Imprima uma frase usando ambas.
#
# Questão 2: Crie uma lista com 5 números inteiros. Use um loop for para imprimir o dobro de cada número.
#
# Questão 3: Crie um dicionário que represente um carro (marca, modelo, ano). Verifique se o ano é anterior a 2010 e imprima "Carro antigo" ou "Carro novo".
#
# Questão 4: Baseado no arquivo dados_produtos.csv, crie uma lista com os preços: [85.50, 220.00, 890.00, 150.00, 180.00]. Escreva um programa que calcule a soma total desses preços e a média de valor dos produtos.
#
# Questão 5: Crie uma estrutura condicional para um sistema de desconto. Se o produto for da categoria "Monitores", aplique 10% de desconto no preço (890.00) e exiba o novo valor. Caso contrário, exiba "Sem desconto para este item".

# %%
#Construa as repostas aqui:
#Questão 1:

#Questão 2:

#Questão 3:

#Questão 4:

#Questão 5:
